# %% [markdown]
# <a href="https://colab.research.google.com/github/xyt556/I-GUIDE-GeoAI-Education/blob/main/notebooks/06-semantic-segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 语义分割
#
# ## 简介
#
# 语义分割对图像中的每个像素进行分类，生成一个与输入图像具有相同空间维度的密集预测图。与使用边界框的目标检测不同，它为每个像素分配一个类别标签（例如，建筑物、道路、植被、水）。
#
# 在遥感领域，语义分割将原始图像转换为专题地图，用于环境监测、城市规划、灾害响应和气候科学。本教程涵盖了四个逐步复杂的应用：
#
# 1. **高分辨率航空影像的建筑物检测**，这是一项二进制分割任务，说明了核心概念。
# 2. **地表水测绘**，涵盖四种工作流程：标准RGB图像、多光谱Sentinel-2数据、NAIP航空摄影和传感器无关的预训练模型。
# 3. **使用预训练的传感器无关模型进行云和云影检测**，说明了用于关键预处理步骤的仅推理分割。
# 4. **土地覆盖分类**，一个多类别分割问题，将每个像素分配给13个土地覆盖类别之一。
#
# 每个应用程序都遵循一致的模式：获取数据、创建训练瓦片、训练U-Net模型、评估性能、运行推理和可视化结果。
#
# ## 学习目标
#
# 通过本教程，您将能够：
#
# - 解释语义分割与图像分类和目标检测的区别
# - 描述编码器-解码器架构和跳跃连接在保持空间细节方面的作用
# - 比较常见的分割架构（U-Net、DeepLabV3+、FPN、PSPNet）和编码器（ResNet、EfficientNet）
# - 解释ImageNet上的迁移学习如何加速地理空间数据的训练
# - 通过对栅格进行切片和将矢量标签栅格化为二进制或多类别掩膜来准备地理空间训练数据
# - 使用`geoai`包和不同的输入波段配置训练语义分割模型
# - 使用损失曲线、IoU和F1分数评估分割性能
# - 使用滑动窗口预测在新图像上运行推理并将栅格预测转换为矢量多边形
# - 将训练好的分割模型发布到Hugging Face Hub并从托管模型运行推理
#
# ## 语义分割基础
#
# **深度学习架构**定义了神经网络的整体结构——数据如何通过层流动以及如何生成预测。**编码器**将输入图像压缩成紧凑的特征表示，而**解码器**则将这些特征重建回原始空间分辨率以生成分割图。
#
# 简而言之：
#
# - **架构** = 工厂蓝图（整体设计和数据流）
# - **编码器** = 预处理线（将输入压缩成学习到的特征）
# - **解码器** = 完成线（将特征重建为像素级输出）
#
# ### 分割架构
#
# 编码器-解码器架构是语义分割的标准。**跳跃连接**连接相应的编码器和解码器层，将高分辨率特征图直接转发到解码器，以便生成空间精确且语义准确的预测。
#
# `segmentation_models.pytorch`库提供了一个将架构与编码器分离的模块化框架：
#
# | 架构 | 核心思想 | 优势 |
# | --- | --- | --- |
# | `unet` | 对称编码器-解码器，每层都有跳跃连接 | 精细的边界划分；在数据有限的情况下表现良好 |
# | `unetplusplus` | 密集跳跃连接（嵌套U-Net） | 比标准U-Net更好的特征融合 |
# | `deeplabv3` | 带ASPP模块的空洞卷积 | 多尺度上下文捕获 |
# | `deeplabv3plus` | 带空洞可分离卷积的编码器-解码器 | 改进边界细节的多尺度上下文 |
# | `fpn` | 来自多个编码器级别的特征金字塔聚合 | 处理不同尺度的物体 |
# | `pspnet` | 用于全局场景上下文的金字塔池化模块 | 适用于需要广泛上下文的场景 |
# | `linknet` | 轻量级解码器，带基于和的跳跃融合 | 具有良好准确性的快速推理 |
# | `manet` | 多尺度注意力引导特征融合 | 注意力机制提高了边界精度 |
# | `pan` | 跨多个尺度的金字塔注意力 | 针对多尺度特征的层次注意力 |
# | `upernet` | 统一感知解析网络 | 全面的多尺度特征集成 |
# | `segformer` | 用于分割的视觉转换器骨干 | 高效的基于转换器的分割 |
# | `dpt` | 密集预测转换器 | 来自视觉转换器令牌的细粒度预测 |
#
# 对于大多数地理空间分割任务，**带有预训练ResNet编码器的U-Net**是一个很好的起点。
#
# ### 编码器和迁移学习
#
# **编码器**将输入图像压缩成有意义的特征表示。**迁移学习**不是从头开始训练，而是从ImageNet上预训练的编码器开始，该编码器已经识别出边缘、纹理和模式，这些都很好地迁移到遥感图像中。
#
# 常见的编码器选择包括`resnet34`、`resnet50`、`efficientnet-b0`和`mobilenet_v2`。
#
# ### 实际实施
#
# `geoai`包基于`segmentation_models.pytorch`，为常见的训练和推理管道提供了高级函数。

# %% [markdown]
# ## 安装
#
# 取消注释以下行以安装所需的包。

# %%
# %pip install -U "geoai-py[extra]"

# %% [markdown]
# ## 导入库
#
# 首先，导入`geoai`包。

# %%
import geoai

# %% [markdown]
# ## 航空影像的建筑物检测
#
# 建筑物检测是一个二元分割问题（建筑物与背景），为分割工作流程提供了清晰的介绍。我们使用高分辨率NAIP航空影像和1米分辨率的3波段RGB输入训练U-Net模型。

# %%
train_raster_url = "https://data.source.coop/opengeos/geoai/naip_rgb_train.tif"
train_vector_url = (
    "https://data.source.coop/opengeos/geoai/naip_train_buildings.geojson"
)
test_raster_url = "https://data.source.coop/opengeos/geoai/naip_test.tif"

# %%
train_raster_path = geoai.download_file(train_raster_url)
train_vector_path = geoai.download_file(train_vector_url)
test_raster_path = geoai.download_file(test_raster_url)

# %% [markdown]
# ### 可视化样本数据
#
# 在训练前检查数据。

# %%
geoai.print_raster_info(train_raster_path, show_preview=False)

# %%
geoai.view_vector_interactive(train_vector_path, tiles=train_raster_path)

# %% [markdown]
# 显示保留的测试图像。

# %%
geoai.view_raster(test_raster_path)

# %% [markdown]
# ### 创建训练瓦片
#
# `export_geotiff_tiles`函数将训练栅格和标签切片成512x512像素的瓦片，步长为256像素，创建重叠的补丁。

# %%
out_folder = "buildings"
tiles = geoai.export_geotiff_tiles(
    in_raster=train_raster_path,
    out_folder=out_folder,
    in_class_data=train_vector_path,
    tile_size=512,
    stride=256,
    buffer_radius=0,
)

# %% [markdown]
# ### 训练模型
#
# 该模型使用带有ImageNet预训练的ResNet34编码器的U-Net架构。

# %%
geoai.train_segmentation_model(
    images_dir=f"{out_folder}/images",
    labels_dir=f"{out_folder}/labels",
    output_dir=f"{out_folder}/unet_models",
    architecture="unet",
    encoder_name="resnet34",
    encoder_weights="imagenet",
    num_channels=3,
    num_classes=2,
    batch_size=8,
    num_epochs=20,
    learning_rate=0.001,
    val_split=0.2,
)

# %% [markdown]
# ### 评估模型
#
# 训练曲线揭示了模型是否有效学习。训练和验证损失之间不断扩大的差距表明过拟合。

# %%
geoai.plot_performance_metrics(
    history_path=f"{out_folder}/unet_models/training_history.pth",
    figsize=(15, 5),
)

# %% [markdown]
# ```text
# === 性能指标摘要 ===
# IoU     - 最佳：0.9012 | 最终：0.8999
# F1      - 最佳：0.9466 | 最终：0.9458
# Precision - 最佳：0.9650 | 最终：0.9605
# Recall  - 最佳：0.9490 | 最终：0.9326
# Val Loss - 最佳：0.0699 | 最终：0.0699
# ===================================
# ```
#
# ### 运行推理
#
# `semantic_segmentation`函数以重叠方式在输入栅格上滑动512x512窗口，将每个补丁通过模型运行，并将预测拼接成无缝输出。我们还生成一个概率图，存储每个像素的每个类别置信度。

# %%
masks_path = "naip_buildings_prediction.tif"
probability_path = "naip_test_probability_map.tif"
model_path = f"{out_folder}/unet_models/best_model.pth"

# %%
geoai.semantic_segmentation(
    input_path=test_raster_path,
    output_path=masks_path,
    model_path=model_path,
    architecture="unet",
    encoder_name="resnet34",
    num_channels=3,
    num_classes=2,
    window_size=512,
    overlap=256,
    batch_size=4,
    probability_path=probability_path,
)

# %% [markdown]
# ### 可视化栅格掩膜
#
# 将预测叠加到原始图像上进行视觉评估。

# %%
geoai.view_raster(
    masks_path,
    nodata=0,
    colormap="binary",
    basemap=test_raster_path,
)

# %% [markdown]
# 在这个两类别示例中，概率图的第2个波段对应于建筑物类别，其中明亮的区域表示高置信度。

# %%
geoai.view_raster(probability_path, indexes=[2], basemap=test_raster_path)

# %% [markdown]
# ### 矢量化预测
#
# `orthogonalize`函数将栅格预测转换为多边形，并将其规范化为干净、直角的形状。

# %%
output_vector_path = "naip_buildings_prediction.geojson"
gdf = geoai.orthogonalize(masks_path, output_vector_path, epsilon=2)

# %% [markdown]
# ### 添加几何属性
#
# 计算面积、周长和形状指数以进行过滤和分析。

# %%
gdf_props = geoai.add_geometric_properties(gdf, area_unit="m2", length_unit="m")

# %% [markdown]
# ### 可视化结果
#
# 显示按面积着色的检测到的建筑物。

# %%
geoai.view_vector_interactive(gdf_props, column="area_m2", tiles=test_raster_path)

# %% [markdown]
# 过滤掉非常小的多边形（< 10平方米）以消除噪声。

# %%
gdf_filtered = gdf_props[(gdf_props["area_m2"] > 10)]
geoai.view_vector_interactive(gdf_filtered, column="area_m2", tiles=test_raster_path)

# %% [markdown]
# 创建一个比较预测足迹（左）与NAIP图像（右）的分割地图。

# %%
geoai.create_split_map(
    left_layer=gdf_filtered,
    right_layer=test_raster_path,
    left_args={"style": {"color": "red", "fillOpacity": 0.2}},
    basemap=test_raster_path,
)

# %% [markdown]
# 清除GPU内存缓存。

# %%
geoai.empty_cache()

# %% [markdown]
# ## 地表水测绘
#
# 地表水测绘对于生态系统监测、洪水风险评估和气候研究至关重要。本节演示了四个逐步更高级的工作流程：
#
# 1. **非地理参考卫星图像**（RGB）介绍了基本工作流程。
# 2. **Sentinel-2多光谱图像**（6个波段）演示了额外的光谱信息如何改善区分。
# 3. **NAIP航空图像**（4个波段，1米分辨率）将工作流程应用于最高分辨率的常用数据。
# 4. **传感器无关的水分割**，使用不需要自定义训练的预训练模型。
#
# ### 使用非地理参考卫星图像进行水测绘
#
# 处理没有地理坐标的标准图像格式（JPG/PNG）是学习核心计算机视觉工作流程的自然起点。
#
# #### 下载样本数据
#
# [水体数据集](https://data.source.coop/opengeos/geoai/waterbody-dataset.zip)包含2,841个图像-掩膜对，涵盖了不同的地理区域和水体类型。
#
# **数据集特征：**
# - **总图像对**：2,841个训练示例
# - **图像格式**：RGB卫星图像（3通道）
# - **掩膜格式**：二元掩膜（255 = 水，0 = 背景）
# - **可变图像尺寸**：256x256到1024x1024+像素
# - **全球覆盖**：来自不同地理区域和水体类型的样本

# %%
url = "https://data.source.coop/opengeos/geoai/waterbody-dataset.zip"

# %%
out_folder = geoai.download_file(url)
print(f"Downloaded dataset to {out_folder}")

# %% [markdown]
# 解压后的数据集包含`images`和`masks`文件夹。

# %% [markdown]
# #### 训练模型
#
# 我们使用带有ImageNet权重初始化的ResNet34编码器的U-Net架构。
#
# 关键训练参数：
# - `num_channels=3`：RGB输入
# - `num_classes=2`：二元分类（背景与水）
# - `batch_size=16`：平衡GPU内存使用和梯度稳定性
# - `learning_rate=0.001`：Adam优化器的标准起点
# - `val_split=0.2`：保留20%的数据用于验证
# - `target_size=(512, 512)`：将可变大小的图像标准化为统一的输入大小
#
# 有关可用架构和编码器的完整列表，请参阅[segmentation_models.pytorch文档](https://smp.readthedocs.io/en/latest/encoders.html)。

# %%
geoai.train_segmentation_model(
    images_dir=f"{out_folder}/images",
    labels_dir=f"{out_folder}/masks",
    output_dir=f"{out_folder}/unet_models",
    architecture="unet",
    encoder_name="resnet34",
    encoder_weights="imagenet",
    num_channels=3,
    num_classes=2,
    batch_size=16,
    num_epochs=20,
    learning_rate=0.001,
    val_split=0.2,
    target_size=(512, 512),
    verbose=True,
)

# %% [markdown]
# 训练会在`unet_models`目录中生成几个输出文件：
#
# - `best_model.pth`：具有最高验证IoU的检查点
# - `final_model.pth`：来自最后一次epoch的检查点
# - `training_history.pth`：用于分析和绘图的完整训练指标
# - `training_summary.txt`：配置和结果的人类可读摘要

# %% [markdown]
# #### 评估模型
#
# **损失**衡量预测与真实值之间的差异；训练损失和验证损失都应该一起下降。
#
# **IoU（交并比）**是标准分割指标，定义为重叠区域除以联合区域，范围从0.0到1.0。
#
# **F1分数**是精确度（预测为正例中正确的比例）和召回率（实际为正例中被找到的比例）的调和平均值，范围从0.0到1.0。

# %%
geoai.plot_performance_metrics(
    history_path=f"{out_folder}/unet_models/training_history.pth",
    figsize=(15, 5),
    verbose=True,
)

# %% [markdown]
# ```text
# === 性能指标摘要 ===
# IoU     - 最佳：0.7079 | 最终：0.7079
# F1      - 最佳：0.8035 | 最终：0.8035
# Precision - 最佳：0.8555 | 最终：0.8309
# Recall  - 最佳：0.8246 | 最终：0.8246
# Val Loss - 最佳：0.3272 | 最终：0.3440
# ===================================
# ```
#
# #### 在单个图像上运行推理
#
# 我们选择一个图像进行演示。更改`index`变量以尝试不同的图像。

# %%
index = 3
test_image_path = f"{out_folder}/images/water_body_{index}.jpg"
ground_truth_path = f"{out_folder}/masks/water_body_{index}.jpg"
prediction_path = f"{out_folder}/prediction/water_body_{index}.png"
model_path = f"{out_folder}/unet_models/best_model.pth"

# %%
geoai.semantic_segmentation(
    input_path=test_image_path,
    output_path=prediction_path,
    model_path=model_path,
    architecture="unet",
    encoder_name="resnet34",
    num_channels=3,
    num_classes=2,
    window_size=512,
    overlap=256,
    batch_size=32,
)

# %% [markdown]
# 并排比较显示了原始图像、预测的水掩膜和真实掩膜。

# %%
fig = geoai.plot_prediction_comparison(
    original_image=test_image_path,
    prediction_image=prediction_path,
    ground_truth_image=ground_truth_path,
    titles=["Original", "Prediction", "Ground Truth"],
    figsize=(15, 5),
    save_path=f"{out_folder}/prediction/water_body_{index}_comparison.png",
    show_plot=True,
)

# %% [markdown]
# #### 在多张图像上运行推理
#
# `semantic_segmentation_batch`函数以一致的参数处理整个图像目录。

# %%
url = "https://data.source.coop/opengeos/geoai/waterbody-dataset-sample.zip"

# %%
data_dir = geoai.download_file(url)
print(f"Downloaded dataset to {data_dir}")

# %% [markdown]
# 设置批量处理的输入和输出目录。

# %%
images_dir = f"{data_dir}/images"
predictions_dir = f"{data_dir}/predictions"

# %%
geoai.semantic_segmentation_batch(
    input_dir=images_dir,
    output_dir=predictions_dir,
    model_path=model_path,
    architecture="unet",
    encoder_name="resnet34",
    num_channels=3,
    num_classes=2,
    window_size=512,
    overlap=256,
    batch_size=4,
    quiet=True,
)

# %% [markdown]
# 清除GPU内存缓存。

# %%
geoai.empty_cache()

# %% [markdown]
# ### 使用Sentinel-2多光谱图像进行水测绘
#
# **Sentinel-2**提供13个光谱波段，分辨率为10-20米。额外的光谱波段，特别是近红外和短波红外，显著改善了水的区分，因为水在这些波长处吸收强烈。
#
# 本分析中使用的六个光谱波段是：
#
# | 波段 | 波长 | 在水检测中的作用 |
# | --- | --- | --- |
# | 蓝色 (490 nm) | 可见光 | 水吸收，大气校正 |
# | 绿色 (560 nm) | 可见光 | 水透明度，植被健康 |
# | 红色 (665 nm) | 可见光 | 陆水对比 |
# | NIR (842 nm) | 近红外 | 强水吸收；关键鉴别器 |
# | SWIR1 (1610 nm) | 短波红外 | 水反射率非常低；极佳的分离器 |
# | SWIR2 (2190 nm) | 短波红外 | 将水与湿土壤和植被分离 |
#
# #### 下载样本数据
#
# 地球地表水数据集包含Sentinel-2 2A级图像，具有6个光谱波段和专家标注的水掩膜，并具有单独的训练和验证拆分。

# %%
url = "https://data.source.coop/opengeos/geoai/dset-s2.zip"
data_dir = geoai.download_file(url, output_path="dset-s2.zip")

# %% [markdown]
# 数据集分为四个目录：
#
# - `tra_scene` / `tra_truth`：训练图像和相应的水掩膜
# - `val_scene` / `val_truth`：独立的验证图像和掩膜

# %%
images_dir = f"{data_dir}/tra_scene"
masks_dir = f"{data_dir}/tra_truth"
tiles_dir = f"{data_dir}/tiles"

# %% [markdown]
# #### 创建训练瓦片
#
# `export_geotiff_tiles_batch`函数一次性处理目录中的所有图像-掩膜对。

# %%
result = geoai.export_geotiff_tiles_batch(
    images_folder=images_dir,
    masks_folder=masks_dir,
    output_folder=tiles_dir,
    tile_size=512,
    stride=384,
    quiet=True,
)

# %% [markdown]
# #### 训练模型
#
# 配置与RGB模型相同，只是`num_channels=6`用于6波段输入。

# %%
geoai.train_segmentation_model(
    images_dir=f"{tiles_dir}/images",
    labels_dir=f"{tiles_dir}/masks",
    output_dir=f"{tiles_dir}/unet_models",
    architecture="unet",
    encoder_name="resnet34",
    encoder_weights="imagenet",
    num_channels=6,
    num_classes=2,
    batch_size=32,
    num_epochs=20,
    learning_rate=0.001,
    val_split=0.2,
)

# %% [markdown]
# #### 评估模型
#
# Sentinel-2模型实现了0.90的最佳验证IoU，显著高于仅RGB模型（0.71），这得益于额外的光谱波段。

# %%
geoai.plot_performance_metrics(
    history_path=f"{tiles_dir}/unet_models/training_history.pth",
    figsize=(15, 5),
)

# %% [markdown]
# ```text
# === 性能指标摘要 ===
# IoU     - 最佳：0.8989 | 最终：0.8989
# F1      - 最佳：0.9323 | 最终：0.9323
# Precision - 最佳：0.9500 | 最终：0.9491
# Recall  - 最佳：0.9453 | 最终：0.9387
# Val Loss - 最佳：0.0550 | 最终：0.0550
# ===================================
# ```
#
# #### 在验证数据上运行推理
#
# 验证集在训练期间完全保留。

# %%
images_dir = f"{data_dir}/val_scene"
masks_dir = f"{data_dir}/val_truth"
predictions_dir = f"{data_dir}/predictions"
model_path = f"{tiles_dir}/unet_models/best_model.pth"

# %%
geoai.semantic_segmentation_batch(
    input_dir=images_dir,
    output_dir=predictions_dir,
    model_path=model_path,
    architecture="unet",
    encoder_name="resnet34",
    num_channels=6,
    num_classes=2,
    window_size=512,
    overlap=256,
    batch_size=32,
    quiet=True,
)

# %% [markdown]
# #### 可视化结果
#
# 使用假彩色合成（波段5-4-3：SWIR1-NIR-Red）、模型预测和真实掩膜进行并排比较。

# %%
image_id = "S2A_L2A_20190318_N0211_R061"
test_image_path = f"{data_dir}/val_scene/{image_id}_6Bands_S2.tif"
ground_truth_path = f"{data_dir}/val_truth/{image_id}_S2_Truth.tif"
prediction_path = f"{data_dir}/predictions/{image_id}_6Bands_S2_mask.tif"
save_path = f"{data_dir}/{image_id}_6Bands_S2_comparison.png"

fig = geoai.plot_prediction_comparison(
    original_image=test_image_path,
    prediction_image=prediction_path,
    ground_truth_image=ground_truth_path,
    titles=["Original", "Prediction", "Ground Truth"],
    figsize=(15, 5),
    save_path=save_path,
    show_plot=True,
    indexes=[5, 4, 3],
    divider=5000,
)

# %% [markdown]
# #### 将模型应用于新的Sentinel-2图像
#
# 我们下载明尼苏达州上空的Sentinel-2场景，并对其运行训练好的模型作为泛化检查。

# %%
s2_path = "s2.tif"
url = "https://data.source.coop/opengeos/geoai/s2-minnesota-2025-08-31-subset.tif"
geoai.download_file(url, output_path=s2_path)

# %%
geoai.view_raster(
    s2_path, indexes=[4, 3, 2], vmin=0, vmax=5000, layer_name="Sentinel-2"
)

# %% [markdown]
# 定义输出路径并运行推理。

# %%
s2_mask = "s2_mask.tif"
model_path = f"{tiles_dir}/unet_models/best_model.pth"

# %%
geoai.semantic_segmentation(
    input_path=s2_path,
    output_path=s2_mask,
    model_path=model_path,
    architecture="unet",
    encoder_name="resnet34",
    num_channels=6,
    num_classes=2,
    window_size=512,
    overlap=256,
    batch_size=32,
)

# %%
geoai.view_raster(
    s2_mask,
    nodata=0,
    colormap="binary",
    layer_name="Water",
    basemap=s2_path,
    basemap_args={"indexes": [4, 3, 2], "vmin": 0, "vmax": 5000},
)

# %% [markdown]
# #### 矢量化水体掩膜
#
# 将预测的栅格掩膜转换为矢量多边形。

# %%
output_vector_path = "s2_water_polygons.geojson"
gdf = geoai.raster_to_vector(
    raster_path=s2_mask,
    output_path=output_vector_path,
    min_area=100,
    simplify_tolerance=None,
)

# %% [markdown]
# #### 平滑水体多边形
#
# 平滑多边形以获得更自然的边界。

# %%
smoothed_path = "s2_water_smoothed.geojson"
gdf = geoai.smooth_vector(
    gdf,
    smooth_iterations=3,
    output_path=smoothed_path,
)

# %% [markdown]
# #### 添加几何属性
#
# 计算每个检测到的水体的面积和周长。

# %%
gdf_props = geoai.add_geometric_properties(gdf, area_unit="m2", length_unit="m")
gdf_props.head()

# %% [markdown]
# #### 过滤小伪影
#
# 移除不太可能是实际水体的小检测区域。

# %%
gdf_filtered = gdf_props[gdf_props["area_m2"] > 100]
print(f"Water bodies detected: {len(gdf_filtered)}")
print(f"Removed {len(gdf_props) - len(gdf_filtered)} small artifacts")

# %% [markdown]
# #### 可视化水体多边形
#
# 显示按面积着色的检测到的水体多边形。

# %%
geoai.view_vector_interactive(
    gdf_filtered,
    column="area_m2",
    opacity=0.5,
    tiles=s2_path,
    tiles_args={"indexes": [4, 3, 2], "vmin": 0, "vmax": 5000},
)

# %% [markdown]
# #### 分割地图比较
#
# 并排比较检测到的水体与原始图像。

# %%
geoai.create_split_map(
    left_layer=gdf_filtered,
    right_layer=s2_path,
    left_args={"style": {"color": "blue", "fillOpacity": 0.3}},
    right_args={"indexes": [4, 3, 2], "vmin": 0, "vmax": 5000},
    basemap=s2_path,
)

# %% [markdown]
# #### 水体面积统计
#
# 分析水体大小的分布。

# %%
print(gdf_filtered["area_m2"].describe())

# %% [markdown]
# #### 保存结果
#
# 保存最终的水体多边形。

# %%
gdf_filtered.to_file("s2_water_bodies_final.geojson", driver="GeoJSON")
print(f"Saved {len(gdf_filtered)} water body polygons to s2_water_bodies_final.geojson")

# %% [markdown]
# ### 使用NAIP航空图像进行水测绘
#
# **NAIP**提供1米分辨率的航空摄影，包含四个波段（红、绿、蓝、近红外）。在此分辨率下，NAIP捕捉了Sentinel-2 10-20米分辨率下不可见的精细特征，例如狭窄的溪流、小池塘和详细的海岸线几何形状。
#
# #### 下载样本数据
#
# 训练和测试图像是经过预处理的NAIP场景，具有相应的栅格化水体掩膜。

# %%
train_raster_url = "https://data.source.coop/opengeos/geoai/naip_water_train.tif"
train_masks_url = "https://data.source.coop/opengeos/geoai/naip_water_masks.tif"
test_raster_url = "https://data.source.coop/opengeos/geoai/naip_water_test.tif"

# %%
train_raster_path = geoai.download_file(train_raster_url)
train_masks_path = geoai.download_file(train_masks_url)
test_raster_path = geoai.download_file(test_raster_url)

# %% [markdown]
# 检查训练栅格元数据。

# %%
geoai.print_raster_info(train_raster_path, show_preview=False)

# %% [markdown]
# #### 可视化样本数据
#
# 将训练水体掩膜叠加在NAIP图像上，然后显示测试图像。

# %%
geoai.view_raster(train_masks_path, nodata=0, opacity=0.5, basemap=train_raster_path)

# %%
geoai.view_raster(test_raster_path)

# %% [markdown]
# #### 创建训练瓦片
#
# 将训练栅格和水体掩膜切片成重叠的512x512瓦片。

# %%
out_folder = "naip"

# %%
tiles = geoai.export_geotiff_tiles(
    in_raster=train_raster_path,
    out_folder=out_folder,
    in_class_data=train_masks_path,
    tile_size=512,
    stride=256,
    buffer_radius=0,
)

# %% [markdown]
# #### 训练模型
#
# NAIP模型使用`num_channels=4`用于四波段输入（RGB + NIR）。

# %%
geoai.train_segmentation_model(
    images_dir=f"{out_folder}/images",
    labels_dir=f"{out_folder}/labels",
    output_dir=f"{out_folder}/models",
    architecture="unet",
    encoder_name="resnet34",
    encoder_weights="imagenet",
    num_channels=4,
    num_classes=2,
    batch_size=8,
    num_epochs=20,
    learning_rate=0.005,
    val_split=0.2,
)

# %% [markdown]
# #### 评估模型
#
# 该模型实现了0.97的最佳验证IoU，反映了高分辨率NAIP图像的优势。

# %%
geoai.plot_performance_metrics(
    history_path=f"{out_folder}/models/training_history.pth",
    figsize=(15, 5),
    verbose=True,
)

# %% [markdown]
# ```text
# === 性能指标摘要 ===
# IoU     - 最佳：0.9695 | 最终：0.9479
# F1      - 最佳：0.9817 | 最终：0.9658
# Precision - 最佳：0.9934 | 最终：0.9648
# Recall  - 最佳：0.9822 | 最终：0.9811
# Val Loss - 最佳：0.0105 | 最终：0.0173
# ===================================
# ```
#
# #### 运行推理
#
# 将训练好的模型应用于训练集中未包含的保留测试图像。

# %%
masks_path = "naip_water_prediction.tif"
model_path = f"{out_folder}/models/best_model.pth"

# %%
geoai.semantic_segmentation(
    input_path=test_raster_path,
    output_path=masks_path,
    model_path=model_path,
    architecture="unet",
    encoder_name="resnet34",
    num_channels=4,
    num_classes=2,
    window_size=512,
    overlap=128,
    batch_size=32,
)

# %%
geoai.view_raster(
    masks_path,
    nodata=0,
    layer_name="Water",
    basemap=test_raster_path,
)

# %% [markdown]
# #### 矢量化和分析预测
#
# 将栅格掩膜转换为矢量多边形并按几何属性过滤。

# %%
output_path = "naip_water_prediction.geojson"
gdf = geoai.raster_to_vector(
    masks_path, output_path, min_area=1000, simplify_tolerance=1
)

# %% [markdown]
# 计算几何属性并显示检测到的水体。

# %%
gdf = geoai.add_geometric_properties(gdf)
len(gdf)

# %%
geoai.view_vector_interactive(gdf, tiles=test_raster_path)

# %% [markdown]
# 过滤掉高度细长的特征（细长比 > 10），以消除道路边缘或阴影等假阳性。

# %%
gdf["elongation"].hist()

# %%
gdf_filtered = gdf[gdf["elongation"] < 10]

# %%
len(gdf_filtered)

# %% [markdown]
# #### 可视化结果
#
# 显示过滤后的水体多边形和分割地图比较。

# %%
geoai.view_vector_interactive(gdf_filtered, tiles=test_raster_path)

# %%
geoai.create_split_map(
    left_layer=gdf_filtered,
    right_layer=test_raster_path,
    left_args={"style": {"color": "red", "fillOpacity": 0.2}},
    basemap=test_raster_path,
)

# %% [markdown]
# ### 传感器无关的水分割
#
# [OmniWaterMask](https://github.com/DPIRD-DMA/OmniWaterMask)提供了一个预训练的、传感器无关的模型，结合了深度学习、NDWI计算和OpenStreetMap参考数据，可实现跨多个传感器（Sentinel-2、NAIP、Landsat、PlanetScope、Maxar）的鲁棒水体检测。
#
# `geoai.segment_water()`函数封装了OmniWaterMask，并内置支持通过[Smoothify](https://github.com/DPIRD-DMA/Smoothify)库进行矢量化和多边形平滑。
#
# #### Sentinel-2水体分割
#
# ##### 下载Sentinel-2数据

# %%
s2_url = (
    "https://data.source.coop/opengeos/geoai/S2A-L2A-20190318-N0211-R061-6Bands-S2.tif"
)
s2_path = geoai.download_file(s2_url)

# %% [markdown]
# ##### 可视化输入数据
#
# 使用假彩色合成（NIR、红、绿）查看Sentinel-2场景。

# %%
geoai.view_raster(s2_path, indexes=[4, 3, 2], vmax=3000)

# %% [markdown]
# ##### 运行水体分割
#
# 使用`"sentinel2"`波段顺序预设运行`segment_water()`。

# %%
s2_mask_path = geoai.segment_water(
    s2_path,
    band_order="sentinel2",
    output_raster="s2_owm_water_mask.tif",
)

# %% [markdown]
# ##### 可视化栅格掩膜

# %%
geoai.view_raster(
    s2_mask_path,
    nodata=0,
    basemap=s2_path,
    opacity=0.5,
    backend="ipyleaflet",
)

# %% [markdown]
# ##### 矢量化和平滑水体

# %%
s2_gdf = geoai.segment_water(
    s2_path,
    band_order="sentinel2",
    output_raster="s2_owm_water_mask.tif",
    output_vector="s2_owm_water_bodies.geojson",
    smooth=True,
    smooth_iterations=3,
    min_size=100,
)

# %% [markdown]
# ##### 过滤小伪影

# %%
s2_filtered = s2_gdf[s2_gdf["area_m2"] > 100]
print(f"Water bodies detected: {len(s2_filtered)}")
print(f"Removed {len(s2_gdf) - len(s2_filtered)} small artifacts")

# %% [markdown]
# ##### 可视化水体多边形

# %%
geoai.view_vector_interactive(
    s2_filtered,
    column="area_m2",
    tiles=s2_path,
    tiles_args={"indexes": [4, 3, 2], "vmax": 3000},
)

# %% [markdown]
# ##### 分割地图比较

# %%
geoai.create_split_map(
    left_layer=s2_filtered,
    right_layer=s2_path,
    left_args={"style": {"color": "blue", "fillOpacity": 0.3}},
    right_args={"indexes": [4, 3, 2], "vmax": 3000},
    basemap=s2_path,
)

# %% [markdown]
# #### NAIP水体分割
#
# ##### 下载NAIP数据

# %%
naip_url = "https://data.source.coop/opengeos/geoai/naip_water_test_subset.tif"
naip_path = geoai.download_file(naip_url)

# %% [markdown]
# ##### 可视化NAIP图像
#
# 使用假彩色合成（NIR、红、绿）查看NAIP场景。

# %%
geoai.view_raster(naip_path, indexes=[4, 1, 2])

# %% [markdown]
# ##### 运行水体分割
#
# 使用`"naip"`波段顺序预设运行`segment_water()`，生成栅格掩膜和平滑的矢量多边形。

# %%
naip_gdf = geoai.segment_water(
    naip_path,
    band_order="naip",
    output_raster="naip_owm_water_mask.tif",
    output_vector="naip_owm_water_bodies.geojson",
    smooth=True,
    smooth_iterations=3,
    min_size=100,
)

# %% [markdown]
# ##### 可视化栅格掩膜

# %%
geoai.view_raster(
    "naip_owm_water_mask.tif",
    nodata=0,
    basemap=naip_path,
    opacity=0.5,
    backend="ipyleaflet",
)

# %% [markdown]
# ##### 过滤小伪影

# %%
naip_filtered = naip_gdf[naip_gdf["area_m2"] > 100]
print(f"Water bodies detected: {len(naip_filtered)}")
print(f"Removed {len(naip_gdf) - len(naip_filtered)} small artifacts")

# %% [markdown]
# ##### 可视化水体多边形

# %%
geoai.view_vector_interactive(
    naip_filtered,
    column="area_m2",
    tiles=naip_path,
)

# %% [markdown]
# ##### 分割地图比较

# %%
geoai.create_split_map(
    left_layer=naip_filtered,
    right_layer=naip_path,
    left_args={"style": {"color": "blue", "fillOpacity": 0.3}},
    basemap=naip_path,
)

# %%
geoai.empty_cache()

# %% [markdown]
# ## 云和云影检测
#
# 云污染是光学遥感中最持久的挑战之一。每个像素被分配到以下四个类别之一：
#
# | 值 | 类别 |
# | --- | --- |
# | 0 | 清晰 |
# | 1 | 厚云 |
# | 2 | 薄云 |
# | 3 | 云影 |
#
# 本节使用GeoAI中集成的[OmniCloudMask](https://github.com/DPIRD-DMA/OmniCloudMask)，这是一个传感器无关的模型，仅需要红、绿和近红外波段。
#
# ### 下载样本数据
#
# 我们使用田纳西州诺克斯维尔上空的Sentinel-2 L2A子集。

# %%
url = "https://data.source.coop/opengeos/geoai/S2C-MSIL2A-20250920T162001-subset.tif"
s2_path = geoai.download_file(url)

# %% [markdown]
# ### 预测云掩膜
#
# 该函数读取红（波段1）、绿（波段2）和近红外（波段4），并对每个像素进行分类。

# %%
pred_path = "cloud_mask.tif"
geoai.predict_cloud_mask_from_raster(
    input_path=s2_path,
    output_path=pred_path,
    red_band=1,
    green_band=2,
    nir_band=4,
    batch_size=4,
    inference_dtype="bf16",
)

# %% [markdown]
# ### 云统计
#
# 像素级统计总结了云和阴影覆盖范围。

# %%
import rasterio as rio
import numpy as np

with rio.open(pred_path) as src:
    pred_array = src.read(1)

stats = geoai.calculate_cloud_statistics(pred_array)
for key, value in stats.items():
    if "percent" in key:
        print(f"{key}: {value:.2f}%")
    else:
        print(f"{key}: {value:,}")

# %% [markdown]
# ```text
# total_pixels: 46,930,758
# clear_pixels: 36,797,157
# thick_cloud_pixels: 6,014,605
# thin_cloud_pixels: 485
# shadow_pixels: 4,118,511
# clear_percent: 78.41%
# cloud_percent: 12.82%
# shadow_percent: 8.78%
# ```
#
# ### 可视化结果
#
# 显示假彩色合成（近红外/红/绿）以及预测的云掩膜。

# %% [markdown]
# ### Visualize Results
#
# Display a false-color composite (NIR/Red/Green) alongside the predicted cloud mask.

# %%
from matplotlib import pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.patches import Patch

with rio.open(s2_path) as src:
    scene_fc = src.read([4, 1, 2]).astype(np.float32)

# Percentile-based contrast stretch per band
for i in range(3):
    band = scene_fc[i]
    p2, p98 = np.percentile(band, (2, 98))
    scene_fc[i] = (band - p2) / (p98 - p2)
scene_fc = np.clip(scene_fc, 0, 1)

cmap = ListedColormap(["green", "white", "gray", "black"])
labels = ["Clear", "Thick Cloud", "Thin Cloud", "Cloud Shadow"]
patches = [
    Patch(facecolor=cmap(i), edgecolor="black", label=labels[i]) for i in range(4)
]

fig, ax = plt.subplots(1, 2, figsize=(20, 10))
ax[0].imshow(scene_fc.transpose(1, 2, 0))
ax[0].set_title("False Color (NIR/R/G)")
ax[0].set_axis_off()
ax[1].imshow(pred_array, cmap=cmap, vmin=0, vmax=3)
ax[1].set_title("Cloud Mask")
ax[1].legend(handles=patches, loc="upper left", fontsize=12)
ax[1].set_axis_off()
plt.tight_layout()
plt.show()

# %% [markdown]
# 放大有云覆盖的区域，检查边界细节。

# %%
from scipy import ndimage

cloud_binary = (pred_array == 1) | (pred_array == 2)
labeled, _ = ndimage.label(cloud_binary)
if labeled.max() > 0:
    sizes = ndimage.sum(cloud_binary, labeled, range(1, labeled.max() + 1))
    largest_label = np.argmax(sizes) + 1
    cy, cx = ndimage.center_of_mass(cloud_binary, labeled, largest_label)
    cy, cx = int(cy), int(cx)
else:
    cy, cx = pred_array.shape[0] // 2, pred_array.shape[1] // 2

# Crop a 1000x1000 window around the center
h, w = pred_array.shape
half = 500
r0, r1 = max(0, cy - half), min(h, cy + half)
c0, c1 = max(0, cx - half), min(w, cx + half)

fig, ax = plt.subplots(1, 2, figsize=(20, 10))
ax[0].imshow(scene_fc[:, r0:r1, c0:c1].transpose(1, 2, 0))
ax[0].contour(pred_array[r0:r1, c0:c1], levels=[0.5, 1.5, 2.5], colors="cyan")
ax[0].set_title("False Color with Cloud Contours")
ax[0].set_axis_off()
ax[1].imshow(pred_array[r0:r1, c0:c1], cmap=cmap, vmin=0, vmax=3)
ax[1].set_title("Cloud Mask (Zoomed)")
ax[1].legend(handles=patches, loc="upper left", fontsize=12)
ax[1].set_axis_off()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 后处理
#
# 清理掩膜，转换为矢量多边形，并平滑边界。

# %%
cleaned_mask_path = "cleaned_mask.tif"
geoai.clean_raster(pred_path, cleaned_mask_path)

# %%
cloud_vector = "cloud_vector.geojson"
cloud_gdf = geoai.raster_to_vector(cleaned_mask_path, cloud_vector)

# %%
smoothed_cloud_gdf = geoai.smooth_vector(
    cloud_gdf, smooth_iterations=3, output_path="smoothed_cloud_vector.geojson"
)

# %% [markdown]
# ### 交互式可视化
#
# 将平滑的云多边形叠加到卫星图像上。

# %%
geoai.view_vector_interactive(
    smoothed_cloud_gdf, tiles=s2_path, tiles_args={"indexes": [4, 1, 2], "vmax": 4000}
)

# %% [markdown]
# 分割地图比较了云掩膜叠加与原始图像。

# %%
geoai.create_split_map(
    left_layer=smoothed_cloud_gdf,
    right_layer=s2_path,
    left_args={"style": {"color": "cyan", "fillOpacity": 0.2}},
    right_args={"indexes": [4, 1, 2], "vmax": 4000},
    basemap=s2_path,
)

# %% [markdown]
# ### 几何属性
#
# 计算每个云多边形的几何属性。

# %%
props_gdf = geoai.add_geometric_properties(cloud_gdf)
props_gdf.describe()

# %% [markdown]
# ### 无云掩膜
#
# 创建可用（无云）像素的二元掩膜。

# %%
cloud_free = geoai.create_cloud_free_mask(pred_array)
usable_pct = cloud_free.sum() / cloud_free.size * 100
print(f"Usable (cloud-free) pixels: {usable_pct:.2f}%")

fig, ax = plt.subplots(1, 2, figsize=(20, 10))
ax[0].imshow(scene_fc.transpose(1, 2, 0))
ax[0].set_title("False Color (NIR/R/G)")
ax[0].set_axis_off()
ax[1].imshow(cloud_free, cmap="RdYlGn", vmin=0, vmax=1)
ax[1].set_title("Cloud-Free Mask (green = usable)")
ax[1].set_axis_off()
plt.tight_layout()
plt.show()

# %% [markdown]
# 清除GPU内存缓存。

# %%
## 土地覆盖分类

**土地覆盖分类**将二元分割扩展到**多类别分割**，其中每个像素被分配到多个类别之一。主要区别在于：`num_classes`增加（本例中为13），损失函数和指标跨所有类别操作，并且类别不平衡可能需要加权损失或过采样。

分类方案遵循[切萨皮克土地覆盖](https://planetarycomputer.microsoft.com/dataset/chesapeake-lc-13)项目，包含13个土地覆盖类别。训练数据由NAIP 4波段航空图像和相应的栅格化土地覆盖标签组成。

### 下载样本数据

训练数据集由NAIP图像瓦片及其相应的13类土地覆盖标签栅格组成。

# %% [markdown]
# ## Land Cover Classification
#
# **Land cover classification** extends binary segmentation to **multi-class segmentation**, where every pixel is assigned to one of many categories. The key differences are: `num_classes` increases (13 in this example), the loss function and metrics operate across all classes, and class imbalance may require weighted losses or oversampling.
#
# The classification scheme follows the [Chesapeake Land Cover](https://planetarycomputer.microsoft.com/dataset/chesapeake-lc-13) project with 13 land cover classes. The training data consists of NAIP 4-band aerial imagery paired with rasterized land cover labels.
#
# ### Download Sample Data
#
# The training dataset consists of a NAIP image tile and its corresponding 13-class land cover label raster.

# %%
train_raster_url = (
    "https://data.source.coop/opengeos/geoai/m_3807511_ne_18_060_20181104.tif"
)
train_landcover_url = (
    "https://data.source.coop/opengeos/geoai/m_3807511_ne_18_060_20181104_landcover.tif"
)
test_raster_url = (
    "https://data.source.coop/opengeos/geoai/m_3807511_se_18_060_20181104.tif"
)

# %%
train_raster_path = geoai.download_file(train_raster_url)
train_landcover_path = geoai.download_file(train_landcover_url)
test_raster_path = geoai.download_file(test_raster_url)

# %% [markdown]
# ### 可视化样本数据
#
# 可视化叠加在NAIP图像上的训练标签，然后创建分割地图。

# %%
legend_args = {"builtin_legend": "Chesapeake", "title": "Land Cover Type"}
geoai.view_raster(
    train_landcover_path, basemap=train_raster_path, legend_args=legend_args
)

# %%
geoai.create_split_map(
    left_layer=train_landcover_path,
    right_layer=train_raster_path,
)

# %% [markdown]
# 显示测试图像。

# %%
geoai.view_raster(test_raster_path)

# %% [markdown]
# ### 创建训练瓦片
#
# 标签图像包含整数类别值（0到12）。

# %%
out_folder = "landcover"

# %%
tiles = geoai.export_geotiff_tiles(
    in_raster=train_raster_path,
    out_folder=out_folder,
    in_class_data=train_landcover_path,
    tile_size=512,
    stride=256,
    buffer_radius=0,
)

# %% [markdown]
# ### 训练模型
#
# 配置使用`num_classes=13`用于完整的土地覆盖方案。

# %%
geoai.train_segmentation_model(
    images_dir=f"{out_folder}/images",
    labels_dir=f"{out_folder}/labels",
    output_dir=f"{out_folder}/unet_models",
    architecture="unet",
    encoder_name="resnet34",
    encoder_weights="imagenet",
    num_channels=4,
    num_classes=13,
    batch_size=8,
    num_epochs=20,
    learning_rate=0.001,
    val_split=0.2,
    verbose=True,
    plot_curves=True,
)

# %% [markdown]
# ### 评估模型
#
# 对于多类别分割，检查验证IoU和损失是否持续改进，以及聚合指标是否掩盖了少数类别上的弱性能。

# %%
geoai.plot_performance_metrics(
    history_path=f"{out_folder}/unet_models/training_history.pth",
    figsize=(15, 5),
    verbose=True,
)

# %% [markdown]
# ### 运行推理
#
# 将模型应用于训练集中没有的相邻NAIP瓦片。

# %%
masks_path = "landcover_prediction.tif"
model_path = f"{out_folder}/unet_models/best_model.pth"

# %%
geoai.semantic_segmentation(
    input_path=test_raster_path,
    output_path=masks_path,
    model_path=model_path,
    architecture="unet",
    encoder_name="resnet34",
    num_channels=4,
    num_classes=13,
    window_size=512,
    overlap=128,
    batch_size=4,
)

# %% [markdown]
# ### 可视化结果
#
# 使用与训练标签相同的方案对预测的类别图进行着色。

# %%
geoai.write_colormap(masks_path, train_landcover_path, output=masks_path)

# %%
geoai.view_raster(masks_path, basemap=test_raster_path, legend_args=legend_args)

# %% [markdown]
# ## 发布和重用模型
#
# 通过[Hugging Face Hub](https://huggingface.co/docs/hub)共享训练好的模型，可以让协作者在无法访问原始训练数据或计算资源的情况下运行推理。

# %%
### 推送到Hugging Face Hub

您需要一个免费的Hugging Face帐户和写权限令牌。

# %% [markdown]
# 上传训练好的模型权重和配置。将`"your-username"`替换为您的Hugging Face用户名。

# %%
repo_url = geoai.push_timm_model_to_hub(
    model_path=model_path,
    repo_id="your-username/chesapeake-landcover-unet-resnet34",
    encoder_name="resnet34",
    architecture="unet",
    num_channels=4,
    num_classes=13,
)
print(repo_url)

# %% [markdown]
# ### 从Hub运行推理
#
# `timm_segmentation_from_hub`函数自动下载并运行模型——无需本地检查点。

# %%
hub_output = "landcover_hub_prediction.tif"
geoai.timm_segmentation_from_hub(
    input_path=test_raster_path,
    output_path=hub_output,
    repo_id="your-username/chesapeake-landcover-unet-resnet34",
    window_size=512,
    overlap=128,
    batch_size=4,
)

# %% [markdown]
# 应用相同的色图并可视化以确认结果匹配。

# %%
geoai.write_colormap(hub_output, train_landcover_path, output=hub_output)
geoai.view_raster(hub_output, basemap=test_raster_path, legend_args=legend_args)

# %% [markdown]
# 清除GPU内存缓存。

# %%
## 主要收获

1. 语义分割为每个像素分配一个类别标签，生成与输入分辨率相同的密集预测图。

2. 带有跳跃连接的编码器-解码器架构是现代分割模型的基础。

3. ImageNet上的迁移学习通过提供预训练的特征提取器加速了训练，这些提取器很好地迁移到遥感中。

4. 相同的工作流程适用于不同的传感器；更改`num_channels`是主要调整。

5. 额外的光谱波段（尤其是NIR和SWIR）显著改善了水等目标的区分。

6. IoU和F1分数是标准分割评估指标，应始终在保留数据上计算。

7. 后处理（矢量化、正则化、几何过滤）将栅格掩膜转换为GIS就绪的矢量特征。

8. 多类别分割通过增加`num_classes`扩展了二元分割，可能需要类别平衡策略。

9. 将模型发布到Hugging Face Hub可以在没有本地训练或数据访问的情况下进行共享和重用。

# %% [markdown]
# ## Key Takeaways
#
# 1. Semantic segmentation assigns a class label to every pixel, producing dense prediction maps at input resolution.
#
# 2. The encoder-decoder architecture with skip connections is the foundation of modern segmentation models.
#
# 3. Transfer learning from ImageNet accelerates training by providing pre-trained feature extractors that transfer well to remote sensing.
#
# 4. The same workflow applies across sensors; changing `num_channels` is the primary adaptation.
#
# 5. Additional spectral bands (especially NIR and SWIR) significantly improve discrimination for targets like water.
#
# 6. IoU and F1 score are the standard segmentation evaluation metrics, and should always be computed on held-out data.
#
# 7. Post-processing (vectorization, regularization, geometric filtering) transforms raster masks into GIS-ready vector features.
#
# 8. Multi-class segmentation extends binary segmentation by increasing `num_classes` and may require class balancing strategies.
#
# 9. Publishing models to Hugging Face Hub enables sharing and reuse without local training or data access.
